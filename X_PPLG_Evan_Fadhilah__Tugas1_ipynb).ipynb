# %% [markdown]
# <a href="https://colab.research.google.com/github/evan828372/dasar-pplg/blob/main/X_PPLG_Evan_Fadhilah__Tugas1_ipynb).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS 1 PRATIK MEMBUAT TIPE DATA DAN VARIABEL
#
# NAMA KELOMPOK: ANTO DONATUR
# NAMA ANGGOTA:
#
# 1.SAFIRA HANA ROSAVA
# 2.ADIKTO DWI PRATAMA HAMDI
# 3.GAVIN ATHALLAH D.
# 4.GHAISAN FAIZA RIZKY
# 5.AULIA RAHMA THALITA
# 6.RENO RUZAIN ARAFAH
# 7.EVAN FADHILAH

# %%
# %%writefile praktik_variabel.cpp
# #include<iostream>
# #include<string>
# using namespace std;
#
# int main() {
# // Dlekrasi Variabel dan Tipe Data
# string namaBarang =" iPhone x";
# int jumlah = 1;
# float harga = 7800000.50;
# char kategori = 'A';
# bool tersedia = true;
#
# //Menampilkan Output ke layar
# cout<< "=== DATA INVENTARIS ==="<<endl;
# cout<< "iPhone x:"<< namaBarang<<endl;
# cout<< "kategori :"<< kategori<<endl;
# cout<< "Jumlah :"<<jumlah<<endl;
# cout<< "Harga :"<<harga<<endl;
# cout<< "Tersedia :"<<tersedia<<endl;
# cout<< "======================="<<endl;
#
# return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel

# %%
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# iPhone x: iPhone x
# kategori :A
# Jumlah :1
# Harga :7.8e+06
# Tersedia :1
# ...
